# %% [markdown]
# <a href="https://colab.research.google.com/github/latifurrahmanalhamida/PCVK_244107027017_M-LATIFUR/blob/main/Modul_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# M LATIFUR RAHMAN ALHAMIDA

# %% [markdown]
# # praktikum

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/singa.png')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/singa.png', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

# simpan File image
#cv.imwrite('('/content/drive/MyDrive/PCVK/singa.png')', img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))  # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0, 255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10, 500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices=np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts=vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # TUGAS

# %%
#1 Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
#jawabanya tidak berubah jika hanya menggunkan figsize kecuali mengubah dpinya, figsize  berguna untuk mengontrol skala dan proporsi figure
# yang akan ditampilkan atau disimpan.

# %%
#2 Tampilkan image dalam channel Red-Blue dan Green-Blue saja
import cv2 as cv
import matplotlib.pyplot as plt

# Membaca gambar dalam mode warna
img_rgb = cv.imread('/content/drive/MyDrive/PCVK/singa.png', cv.IMREAD_COLOR)
img_rgb = cv.cvtColor(img_rgb, cv.COLOR_BGR2RGB)

# Membuat gambar Red-Blue
red_blue_image = img_rgb.copy()
red_blue_image[:, :, 1] = 0
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(red_blue_image)
plt.title('Red-Blue')
plt.show()

# %%
img_rgb = cv.cvtColor(img_rgb, cv.COLOR_BGR2RGB)
# Membuat gambar Green-Blue (menghilangkan channel merah)
green_blue_image = img_rgb.copy()
green_blue_image[:, :, 0] = 0  # Setel channel merah ke 0

# Menampilkan hasil
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 2)
plt.imshow(green_blue_image)
plt.title('Green-Blue Channel')

plt.show()

# %%
#3 Tampilkan image baris ke 20-115, kolom 25-120

# %%
#4 Tampilkan image baris ke 5-30, semua kolom, channel Red saja

# %%
#5 Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random
import matplotlib.pyplot as plt
import numpy as np
import random
fig, ax = plt.subplots()
# Mengatur batas figure
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)

# Membuat 5 kotak
for _ in range(5):
    width = random.randint(5, 20)
    height = random.randint(5, 20)
    x = random.randint(0, 100 - width)
    y = random.randint(0, 100 - height)
    color = np.random.rand(3,)
    rect = plt.Rectangle((x, y), width, height, color=color)
    ax.add_patch(rect)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Gambar 5 Kotak dengan Ukuran dan Warna Acak')
plt.show()

# %%
#6 Tampilkan image dengan posisi terbalik
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(img5)
plt.title('Gambar Terbalik')
plt.axis('off')
plt.show()

# %%
#7
